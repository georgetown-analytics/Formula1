# %%
import pandas as pd



c = pd.read_csv('circuits.csv')


#print(c)

##read headers
print(c.columns)

#print(c[['circuitId', 'circuitRef', 'name', 'location']])


##Read each Row
#print(c.iloc[2])


##read a specific location (R,C)
#print(c.iloc[2,2])

# for index, row in c.iterrows():
#     print(index, row['location'])
    
for index, row in c.iterrows():
    print(index, row['circuitId'] ,row['location'])
# Out:
# Index(['circuitId', 'circuitRef', 'name', 'location', 'country', 'lat', 'lng',
#        'alt', 'url'],
#       dtype='object')
# 0 1 Melbourne
# 1 2 Kuala Lumpur
# 2 3 Sakhir
# 3 4 Montmel�_
# 4 5 Istanbul
# 5 6 Monte-Carlo
# 6 7 Montreal
# 7 8 Magny Cours
# 8 9 Silverstone
# 9 10 Hockenheim
# 10 11 Budapest
# 11 12 Valencia
# 12 13 Spa
# 13 14 Monza
# 14 15 Marina Bay
# 15 16 Oyama
# 16 17 Shanghai
# 17 18 Ṣo Paulo
# 18 19 Indianapolis
# 19 20 N�_rburg
# 20 21 Imola
# 21 22 Suzuka
# 22 23 Spielburg
# 23 24 Abu Dhabi
# 24 25 Buenos Aires
# 25 26 Jerez de la Frontera
# 26 27 Estoril
# 27 28 Okayama
# 28 29 Adelaide
# 29 30 Midrand
# 30 31 Castle Donington
# 31 32 Mexico City
# 32 33 Phoenix
# 33 34 Le Castellet
# 34 35 Yeongam County
# 35 36 Rio de Janeiro
# 36 37 Detroit
# 37 38 Kent
# 38 39 Zandvoort
# 39 40 Heusden-Zolder
# 40 41 Dijon
# 41 42 Dallas
# 42 43 California
# 43 44 Nevada
# 44 45 Madrid
# 45 46 New York State
# 46 47 Anderstorp
# 47 48 Ontario
# 48 49 Barcelona
# ...
